# %%
from rectpack import newPacker

# Define the rectangles and bins
rectangles = [(12.55,2.65),
(12.1,2.9),
(3,2),
(3.95,2.65),
(1.5,1.5),
(3.2,2.5),
(12.55,2.65),
(10.85,2.24),
(10.85,2.24),
(2,1.5),
(1,2),
(10.85,2.24),
(1.76,1.76),
(10.85,2.24),
(12.1,2.9),
(9.65,2.82),
(4.32,2.48),
(3,2),
(2.5,1.5),
(6.1,2.1),
(8.1,2.8),
(6.8,2.75),
(10.6,2.8),
(2,1.5),
(8.5,2.8),
(9.45,2.85),
(4.88,2.48),
(10.7,2.85),
(8,2.7),
(5.45,3.6),
(3.7,1.75),
(2.6,2),
(7,7),
(1,1),
(8.7,2.2),
(4.8,2.7),
(6.3,2.75),
(4.32,2.48),
(6,2.2),
(4.3,1.3),
(7,2.2),
(5.7,3.2),
(2.85,1.6),
(1.425,0.8),
(10.6,2.52),
(2.4,1.5),
(8.65,2.6),
(2.25,2.2),
(1.6,1.4),
(3.55,2.45),
(4.6,3.6),
(4.7,2.55),
(9.7,2.25),
(12,2.95),
(7,2.5),
(3.1,2.85),
(1.2,0.8),
(4,2.42),
(2.5,1),
(7,2.2),
(6.08,2.42),
(12,2.95),
(8.92,2.63),
(8.92,2.63),
(6,2.5),
(6,2.5),
(6,2.5),
(6,2.5),
(13.4,2.5),
(5.6,1.9),
(8,1.5),
(8,1.5),
(2.75,1.2),
(2.45,1.65),
(2.7,1.5),
(3,2.5),
(8.15,2.95),
(8.15,2.95),
(5.35,3.65),
(7.43,1.42),
(2.4,3.8),
(9.02,3.1),
(8,1),
(8.92,2.63),
(3,2.9),
(1,1),
(8.92,2.63),
(8,1),
(6.5,2.61),
(3.7,2),
(1.2,0.5),
(3,2),
(4.7,3.6),
(8.5,3.35),
(6.5,2.61),
(4,1.4),
(4.7,3.6),
(1.5,1.5),
(7.52,2.57),
(7.05,2.8),
(11.5,2.9),
(9.4,2.75),
(3.2,2.4),
(8.9,3.36),
(2.35,2),
(8.75,3.05),
(4.6,3.55),
(4.7,2.55),
(4.7,2.55),
(11,2.22),
(18.2,2.7),
(18.2,2.7)]
bins = [(63.5, 21.3)]

# Initialize the packer
packer = newPacker()

# Add the rectangles to the packing queue
for r in rectangles:
    packer.add_rect(*r)

# Add the bins where the rectangles will be placed
for b in bins:
    packer.add_bin(*b)

# Start packing
packer.pack()

# Retrieve and print the results
for abin in packer:
    print(f"Bin {abin.bid} ({abin.width}x{abin.height}):")
    for rect in abin:
        print(f"  Placed rectangle {rect.rid} at ({rect.x}, {rect.y}), size ({rect.width}x{rect.height})")
# Out:
# Bin None (63.5x21.3):
#   Placed rectangle None at (0, 0), size (2.7x18.2)
#   Placed rectangle None at (0, 18.2), size (18.2x2.7)
#   Placed rectangle None at (2.7, 0), size (7x7)
#   Placed rectangle None at (9.7, 0), size (2.95x12)
#   Placed rectangle None at (2.7, 12), size (12x2.95)
#   Placed rectangle None at (2.7, 14.95), size (12.1x2.9)
#   Placed rectangle None at (14.7, 0), size (2.9x12.1)
#   Placed rectangle None at (14.7, 12.1), size (13.4x2.5)
#   Placed rectangle None at (17.599999999999998, 0), size (2.9x11.5)
#   Placed rectangle None at (14.8, 14.6), size (12.55x2.65)
#   Placed rectangle None at (18.2, 17.25), size (12.55x2.65)
#   Placed rectangle None at (20.499999999999996, 0), size (2.85x10.7)
#   Placed rectangle None at (23.349999999999998, 0), size (3.36x8.9)
#   Placed rectangle None at (23.349999999999998, 8.9), size (10.6x2.8)
#   Placed rectangle None at (26.709999999999997, 0), size (3.35x8.5)
#   Placed rectangle None at (30.75, 11.7), size (3.1x9.02)
#   Placed rectangle None at (30.06, 0), size (9.65x2.82)
#   Placed rectangle None at (33.85, 11.7), size (2.85x9.45)
#   Placed rectangle None at (30.06, 2.82), size (10.6x2.52)
#   Placed rectangle None at (30.06, 5.34), size (8.75x3.05)
#   Placed rectangle None at (39.71, 0), size (9.4x2.75)
#   Placed rectangle None at (33.949999999999996, 8.39), size (11x2.22)
#   Placed rectangle None at (38.81, 5.34), size (10.85x2.24)
#   Placed rectangle None at (40.66, 2.75), size (10.85x2.24)
#   Placed rectangle None at (49.11, 0), size (10.85x2.24)
#   Placed rectangle None at (51.51, 2.24), size (10.85x2.24)
#   Placed rectangle None at (36.7, 10.610000000000001), size (2.95x8.15)
#   Placed rectangle None at (39.650000000000006, 10.610000000000001), size (2.95x8.15)
#   Placed rectangle None at (42.60000000000001, 10.610000000000001), size (2.8x8.5)
#   Placed rectangle None at (44.949999999999996, 7.58), size (8.92x2.63)
#   Placed rectangle None at (51.51, 4.48), size (8.92x2.63)
#   Placed rectangle None at (60.43, 4.48), size (2.63x8.92)
#   Placed rectangle None at (49.660000000000004, 10.21), size (8.92x2.63)
#   Placed rectangle None at (45.400000000000006, 12.84), size (2.8x8.1)
#   Placed rectangle None at (49.660000000000004, 12.84), size (8.65x2.6)
#   Placed rectangle None at (48.2, 15.44), size (9.7x2.25)
#   Placed rectangle None at (48.2, 17.689999999999998), size (8x2.7)
#   Placed rectangle None at (56.2, 17.689999999999998), size (7.05x2.8)
#   Placed rectangle None at (2.7, 7), size (5.45x3.6)
#   Placed rectangle None at (53.87, 7.11), size (6.3x2.75)
#   Placed rectangle None at (58.31, 13.4), size (4.7x3.6)
#   Placed rectangle None at (36.7, 19.11), size (6.1x2.1)
#   Placed rectangle None at (28.1, 11.7), size (2.48x4.88)
#   Placed rectangle None at (12.649999999999999, 0), size (1.5x8)
#   Placed rectangle None at (45.400000000000006, 10.21), size (4x2.42)
#   Placed rectangle None at (18.2, 19.9), size (8x1)
#   Placed rectangle None at (12.649999999999999, 8), size (2x3.7)
#   Placed rectangle None at (59.96, 0), size (3x2)
#   Placed rectangle None at (2.7, 10.6), size (4x1.4)
#   Placed rectangle None at (26.2, 19.9), size (4.3x1.3)
#   Placed rectangle None at (42.800000000000004, 19.11), size (2.6x2)
#   Placed rectangle None at (58.580000000000005, 9.86), size (1.6x2.85)
#   Placed rectangle None at (8.15, 7), size (1.5x2.7)
#   Placed rectangle None at (49.660000000000004, 4.99), size (1.65x2.45)
#   Placed rectangle None at (48.2, 12.63), size (1.2x2.75)
#   Placed rectangle None at (8.15, 9.7), size (1.5x2)
#   Placed rectangle None at (33.949999999999996, 10.610000000000001), size (2.5x1)
#   Placed rectangle None at (20.499999999999996, 10.7), size (1.6x1.4)
#   Placed rectangle None at (62.36, 2), size (1x2)
#   Placed rectangle None at (38.81, 7.58), size (1.425x0.8)
#   Placed rectangle None at (22.099999999999998, 10.7), size (1x1)
#   Placed rectangle None at (6.7, 10.6), size (1x1)
#   Placed rectangle None at (40.235, 7.58), size (1.2x0.8)
#   Placed rectangle None at (49.11, 2.24), size (1.2x0.5)

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from rectpack import newPacker

# Define the rectangles and bins
rectangles = [(12.55,2.65), (12.1,2.9),
(3,2),
(3.95,2.65),
(1.5,1.5),
(3.2,2.5),
(12.55,2.65),
(10.85,2.24),
(10.85,2.24),
(2,1.5),
(1,2),
(10.85,2.24),
(1.76,1.76),
(10.85,2.24),
(12.1,2.9),
(9.65,2.82),
(4.32,2.48),
(3,2),
(2.5,1.5),
(6.1,2.1),
(8.1,2.8),
(6.8,2.75),
(10.6,2.8),
(2,1.5),
(8.5,2.8),
(9.45,2.85),
(4.88,2.48),
(10.7,2.85),
(8,2.7),
(5.45,3.6),
(3.7,1.75),
(2.6,2),
(7,7),
(1,1),
(8.7,2.2),
(4.8,2.7),
(6.3,2.75),
(4.32,2.48),
(6,2.2),
(4.3,1.3),
(7,2.2),
(5.7,3.2),
(2.85,1.6),
(1.425,0.8),
(10.6,2.52),
(2.4,1.5),
(8.65,2.6),
(2.25,2.2),
(1.6,1.4),
(3.55,2.45),
(4.6,3.6),
(4.7,2.55),
(9.7,2.25),
(12,2.95),
(7,2.5),
(3.1,2.85),
(1.2,0.8),
(4,2.42),
(2.5,1),
(7,2.2),
(6.08,2.42),
(12,2.95),
(8.92,2.63),
(8.92,2.63),
(6,2.5),
(6,2.5),
(6,2.5),
(6,2.5),
(13.4,2.5),
(5.6,1.9),
(8,1.5),
(8,1.5),
(2.75,1.2),
(2.45,1.65),
(2.7,1.5),
(3,2.5),
(8.15,2.95),
(8.15,2.95),
(5.35,3.65),
(7.43,1.42),
(2.4,3.8),
(9.02,3.1),
(8,1),
(8.92,2.63),
(3,2.9),
(1,1),
(8.92,2.63),
(8,1),
(6.5,2.61),
(3.7,2),
(1.2,0.5),
(3,2),
(4.7,3.6),
(8.5,3.35),
(6.5,2.61),
(4,1.4),
(4.7,3.6),
(1.5,1.5),
(7.52,2.57),
(7.05,2.8),
(11.5,2.9),
(9.4,2.75),
(3.2,2.4),
(8.9,3.36),
(2.35,2),
(8.75,3.05),
(4.6,3.55),
(4.7,2.55),
(4.7,2.55),
(11,2.22),
(18.2,2.7),
(18.2,2.7),
]
bins = [(63.5, 21.3), (63.5, 21.3), (5.8, 18.30), (5.8, 18.3)]

# Initialize the packer
packer = newPacker()

# Add the rectangles to the packing queue
for r in rectangles:
    packer.add_rect(*r)

# Add the bins where the rectangles will be placed
for b in bins:
    packer.add_bin(*b)

# Start packing
packer.pack()

# Plotting the results
fig, ax = plt.subplots(figsize=(15, 8))

colors = ['red', 'blue', 'green', 'orange', 'purple', 'cyan']

for abin in packer:
    bin_rect = Rectangle((0, 0), abin.width, abin.height, edgecolor='black', facecolor='none')
    ax.add_patch(bin_rect)
    for i, rect in enumerate(abin):
        color = colors[i % len(colors)]
        r = Rectangle((rect.x, rect.y), rect.width, rect.height, edgecolor='black', facecolor=color)
        ax.add_patch(r)
        ax.text(rect.x + rect.width / 2, rect.y + rect.height / 2, f"{rect.width}x{rect.height}",
                ha='center', va='center', color='white')

ax.set_xlim(0, max(b[0] for b in bins))
ax.set_ylim(0, max(b[1] for b in bins))
ax.set_aspect('equal')
plt.gca().invert_yaxis()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from rectpack import newPacker

# Define the rectangles and bins
rectangles = [(7.2,2.5),(1.25,1.25),(7.2,2.5),(7.2,2.5),(7.2,2.5),(7.2,2.5),(13.4,2.5),(13.4,2.5),(13.4,2.5),(13.4,2.5),
              (12.8,2.43),(12.8,2.43),(7.2,2.5),(7.2,2.5),(7.2,2.5),(7.2,2.5),(7.2,2.5),(13.4,2.5),(13.4,2.5),(13.4,2.5),
              (13.4,2.5),(13.4,2.5),(13.4,2.5),(13.4,2.5),(13.4,2.5),(13.4,2.5),(13.4,2.5),(7.2,2.5),(7.2,2.5),(7.2,2.5),
              (7.2,2.5),(7.2,2.5),(7.2,2.5),(7.2,2.5),(7.2,2.5),(3.1,2.9),(8.9,3.36),(6.6,2.68),(6.5,2.7),(8,2.54),(7.15,2.3),
              (4.2,2.1),(9.8,3.1),(3,2),(6.5,4.3),(13.35,2.82),(10.8,2.4),(10.8,2.4),(10.8,2.4),(10.8,2.4),(10.8,2.4),(10.8,2.4),
              (10.8,2.4),(10.8,2.4),(10.8,2.4),(10.8,2.4),(10.8,2.4),(9,1),(1,1),(9,1),(11.2,1.65),(11.2,2.3),(1,1),
              (10.7,2.2),(8,1),(1,1),(8,1),(10.7,2.15),(2,1.5),(11.25,1.7),(2.1,1.12),(10.9,2.2),(13.5,2.65),(18.2,2.7),
              (18.2,2.7),(1,0.5),(2,2),(10.8,2.4),(10.8,2.4),(10.8,2.4),(10.8,2.4),(10.8,2.4),(10.8,2.4),(10.8,2.4),
              (10.8,2.4),(10.8,2.4),(10,0.5),(10,0.5),(10,0.5),(10,0.5),(12.1,2.9)
]
bins = [(63.5, 21.3), (63.5, 21.3), (5.8, 18.30), (5.8, 18.3)]

# Initialize the packer
packer = newPacker()

# Add the rectangles to the packing queue
for r in rectangles:
    packer.add_rect(*r)

# Add the bins where the rectangles will be placed
for b in bins:
    packer.add_bin(*b)

# Start packing
packer.pack()

# Plotting the results
fig, ax = plt.subplots(figsize=(15, 8))

colors = ['red', 'blue', 'green', 'orange', 'purple', 'cyan']

for abin in packer:
    bin_rect = Rectangle((0, 0), abin.width, abin.height, edgecolor='black', facecolor='none')
    ax.add_patch(bin_rect)
    for i, rect in enumerate(abin):
        color = colors[i % len(colors)]
        r = Rectangle((rect.x, rect.y), rect.width, rect.height, edgecolor='black', facecolor=color)
        ax.add_patch(r)
        ax.text(rect.x + rect.width / 2, rect.y + rect.height / 2, f"{rect.width}x{rect.height}",
                ha='center', va='center', color='white')

ax.set_xlim(0, max(b[0] for b in bins))
ax.set_ylim(0, max(b[1] for b in bins))
ax.set_aspect('equal')
plt.gca().invert_yaxis()
plt.show()

# %%
from rectpack import newPacker

# Definisikan ukuran persegi panjang yang akan dikemas
rectangles = [
    (12.55, 2.65), (12.1, 2.9), (3, 2), (3.95, 2.65), (1.5, 1.5), (3.2, 2.5),
    (12.55, 2.65), (10.85, 2.24), (10.85, 2.24), (2, 1.5), (1, 2), (10.85, 2.24),
    (1.76, 1.76), (10.85, 2.24), (12.1, 2.9), (9.65, 2.82), (4.32, 2.48), (3, 2),
    (2.5, 1.5), (6.1, 2.1), (8.1, 2.8), (6.8, 2.75), (10.6, 2.8), (2, 1.5),
    (8.5, 2.8), (9.45, 2.85), (4.88, 2.48), (10.7, 2.85), (8, 2.7), (5.45, 3.6),
    (3.7, 1.75), (2.6, 2), (7, 7), (1, 1), (8.7, 2.2), (4.8, 2.7), (6.3, 2.75),
    (4.32, 2.48), (6, 2.2), (4.3, 1.3), (7, 2.2), (5.7, 3.2), (2.85, 1.6),
    (1.425, 0.8), (10.6, 2.52), (2.4, 1.5), (8.65, 2.6), (2.25, 2.2), (1.6, 1.4),
    (3.55, 2.45), (4.6, 3.6), (4.7, 2.55), (9.7, 2.25), (12, 2.95), (7, 2.5),
    (3.1, 2.85), (1.2, 0.8), (4, 2.42), (2.5, 1), (7, 2.2), (6.08, 2.42), (12, 2.95),
    (8.92, 2.63), (8.92, 2.63), (6, 2.5), (6, 2.5), (6, 2.5), (6, 2.5), (13.4, 2.5),
    (5.6, 1.9), (8, 1.5), (8, 1.5), (2.75, 1.2), (2.45, 1.65), (2.7, 1.5), (3, 2.5),
    (8.15, 2.95), (8.15, 2.95), (5.35, 3.65), (7.43, 1.42), (2.4, 3.8), (9.02, 3.1),
    (8, 1), (8.92, 2.63), (3, 2.9), (1, 1), (8.92, 2.63), (8, 1), (6.5, 2.61),
    (3.7, 2), (1.2, 0.5), (3, 2), (4.7, 3.6), (8.5, 3.35), (6.5, 2.61), (4, 1.4),
    (4.7, 3.6), (1.5, 1.5), (7.52, 2.57), (7.05, 2.8), (11.5, 2.9), (9.4, 2.75),
    (3.2, 2.4), (8.9, 3.36), (2.35, 2), (8.75, 3.05), (4.6, 3.55), (4.7, 2.55),
    (4.7, 2.55), (11, 2.22), (18.2, 2.7), (18.2, 2.7)
]

# Buat objek Packer
packer = newPacker()

# Tambahkan persegi panjang ke dalam packer
for rect in rectangles:
    packer.add_rect(*rect)

# Tentukan ukuran bin (wadah) tempat persegi panjang akan dikemas
bin_width = 20  # Atur ukuran bin sesuai kebutuhan
bin_height = 20  # Atur ukuran bin sesuai kebutuhan
packer.add_bin(bin_width, bin_height, count=10)  # Bisa menambahkan beberapa bin

# Jalankan proses pengepakan
packer.pack()

# Tampilkan hasil pengepakan
for abin in packer:
    print(f"Bin: {abin.width} x {abin.height}")
    for rect in abin:
        print(f"Rect: {rect.width} x {rect.height} at (x: {rect.x}, y: {rect.y})")

# Tampilkan hasil akhir dalam format yang mudah dibaca
for i, abin in enumerate(packer):
    print(f"\nBin {i+1} ({abin.width}x{abin.height}):")
    for rect in abin:
        print(f"  Rect {rect.width}x{rect.height} at (x: {rect.x}, y: {rect.y})")
# Out:
# Bin: 20 x 20
# Rect: 18.2 x 2.7 at (x: 0, y: 0)
# Rect: 18.2 x 2.7 at (x: 0, y: 2.7)
# Rect: 7 x 7 at (x: 0, y: 5.4)
# Rect: 12 x 2.95 at (x: 7, y: 5.4)
# Rect: 12 x 2.95 at (x: 7, y: 8.350000000000001)
# Rect: 12.1 x 2.9 at (x: 7, y: 11.3)
# Rect: 12.1 x 2.9 at (x: 0, y: 14.200000000000001)
# Rect: 13.4 x 2.5 at (x: 0, y: 17.1)
# Rect: 7.05 x 2.8 at (x: 12.1, y: 14.200000000000001)
# Rect: 6.3 x 2.75 at (x: 13.4, y: 17.0)
# Rect: 1 x 8 at (x: 19, y: 0)
# Rect: 1.76 x 1.76 at (x: 0, y: 12.4)
# Rect: 1 x 2.5 at (x: 19, y: 8)
# Rect: 0.8 x 1.425 at (x: 18.2, y: 0)
# Rect: 0.8 x 1.2 at (x: 18.2, y: 1.425)
# Bin: 20 x 20
# Rect: 11.5 x 2.9 at (x: 0, y: 0)
# Rect: 2.65 x 12.55 at (x: 0, y: 2.9)
# Rect: 12.55 x 2.65 at (x: 0, y: 15.450000000000001)
# Rect: 2.85 x 10.7 at (x: 2.65, y: 2.9)
# Rect: 3.36 x 8.9 at (x: 5.5, y: 2.9)
# Rect: 10.6 x 2.8 at (x: 8.86, y: 2.9)
# Rect: 8.5 x 3.35 at (x: 5.5, y: 11.8)
# Rect: 9.02 x 3.1 at (x: 8.86, y: 5.699999999999999)
# Rect: 9.65 x 2.82 at (x: 8.86, y: 8.799999999999999)
# Rect: 2.95 x 8.15 at (x: 14.0, y: 11.62)
# Rect: 2.95 x 8.15 at (x: 16.95, y: 11.62)
# Rect: 8.5 x 2.8 at (x: 11.5, y: 0)
# Rect: 2 x 3 at (x: 17.88, y: 5.699999999999999)
# Rect: 1.4 x 4 at (x: 12.55, y: 15.15)
# Rect: 2.85 x 1.6 at (x: 2.65, y: 13.6)
# Rect: 0.5 x 1.2 at (x: 19.46, y: 8.7)
# Bin: 20 x 20
# Rect: 9.45 x 2.85 at (x: 0, y: 0)
# Rect: 2.52 x 10.6 at (x: 0, y: 2.85)
# Rect: 8.75 x 3.05 at (x: 9.45, y: 0)
# Rect: 9.4 x 2.75 at (x: 0, y: 13.45)
# Rect: 11 x 2.22 at (x: 0, y: 16.2)
# Rect: 2.24 x 10.85 at (x: 9.4, y: 3.05)
# Rect: 2.24 x 10.85 at (x: 11.64, y: 3.05)
# Rect: 2.24 x 10.85 at (x: 13.88, y: 3.05)
# Rect: 2.24 x 10.85 at (x: 16.12, y: 3.05)
# Rect: 8.92 x 2.63 at (x: 11, y: 13.899999999999999)
# Rect: 8.92 x 2.63 at (x: 11, y: 16.529999999999998)
# Rect: 2.63 x 8.92 at (x: 2.52, y: 2.85)
# Rect: 2.63 x 8.92 at (x: 5.15, y: 2.85)
# Rect: 8 x 1.5 at (x: 0, y: 18.419999999999998)
# Rect: 1.42 x 7.43 at (x: 7.78, y: 2.85)
# Rect: 1.3 x 4.3 at (x: 18.36, y: 0)
# Rect: 2.7 x 1.5 at (x: 8, y: 18.419999999999998)
# Rect: 2.45 x 1.65 at (x: 2.52, y: 11.77)
# Rect: 1.5 x 2.4 at (x: 7.78, y: 10.28)
# Rect: 1.5 x 1.5 at (x: 9.4, y: 13.899999999999999)
# Rect: 1.5 x 1.5 at (x: 18.36, y: 4.3)
# Bin: 20 x 20
# Rect: 8.1 x 2.8 at (x: 0, y: 0)
# Rect: 8.65 x 2.6 at (x: 8.1, y: 0)
# Rect: 2.25 x 9.7 at (x: 16.75, y: 0)
# Rect: 8 x 2.7 at (x: 8.1, y: 2.6)
# Rect: 5.45 x 3.6 at (x: 0, y: 2.8)
# Rect: 3.65 x 5.35 at (x: 0, y: 9.7)
# Rect: 2.57 x 7.52 at (x: 5.45, y: 2.8)
# Rect: 8.7 x 2.2 at (x: 8.02, y: 5.300000000000001)
# Rect: 6.8 x 2.75 at (x: 8.02, y: 7.500000000000001)
# Rect: 5.7 x 3.2 at (x: 0, y: 15.049999999999999)
# Rect: 7 x 2.5 at (x: 3.65, y: 10.32)
# Rect: 2.61 x 6.5 at (x: 5.7, y: 12.82)
# Rect: 2.61 x 6.5 at (x: 8.31, y: 12.82)
# Rect: 4.7 x 3.6 at (x: 14.82, y: 9.7)
# Rect: 3.6 x 4.7 at (x: 10.92, y: 10.25)
# Rect: 3.6 x 4.6 at (x: 10.92, y: 14.95)
# Rect: 4.6 x 3.55 at (x: 14.52, y: 13.299999999999999)
# Rect: 4.8 x 2.7 at (x: 14.52, y: 16.849999999999998)
# Rect: 4.88 x 2.48 at (x: 0, y: 6.4)
# Rect: 1 x 8 at (x: 19.0, y: 0)
# Rect: 3.7 x 1.75 at (x: 0, y: 18.25)
# Rect: 2 x 1.5 at (x: 3.7, y: 18.25)
# Rect: 2 x 1.5 at (x: 3.65, y: 12.82)
# Rect: 1.6 x 1.4 at (x: 3.65, y: 8.88)
# Rect: 1 x 1 at (x: 19.0, y: 8)
# Bin: 20 x 20
# Rect: 7 x 2.2 at (x: 0, y: 0)
# Rect: 7 x 2.2 at (x: 7, y: 0)
# Rect: 6 x 2.5 at (x: 14, y: 0)
# Rect: 6 x 2.5 at (x: 0, y: 2.2)
# Rect: 6 x 2.5 at (x: 6, y: 2.2)
# Rect: 6 x 2.5 at (x: 12, y: 2.5)
# Rect: 6.08 x 2.42 at (x: 0, y: 4.7)
# Rect: 2.2 x 6 at (x: 6.08, y: 4.7)
# Rect: 2.1 x 6.1 at (x: 8.280000000000001, y: 4.7)
# Rect: 1.5 x 8 at (x: 10.38, y: 4.7)
# Rect: 4.7 x 2.55 at (x: 0, y: 7.12)
# Rect: 4.7 x 2.55 at (x: 0, y: 9.67)
# Rect: 4.7 x 2.55 at (x: 4.7, y: 10.8)
# Rect: 4.32 x 2.48 at (x: 0, y: 12.219999999999999)
# Rect: 2.48 x 4.32 at (x: 0, y: 14.7)
# Rect: 1.9 x 5.6 at (x: 18, y: 2.5)
# Rect: 2.65 x 3.95 at (x: 2.48, y: 14.7)
# Rect: 4 x 2.42 at (x: 11.88, y: 5.0)
# Rect: 3.8 x 2.4 at (x: 11.88, y: 7.42)
# Rect: 3.1 x 2.85 at (x: 15.68, y: 8.1)
# Rect: 3 x 2.9 at (x: 11.88, y: 9.82)
# Rect: 2.45 x 3.55 at (x: 9.4, y: 12.7)
# Rect: 2.5 x 3.2 at (x: 5.13, y: 16.25)
# Rect: 3.2 x 2.4 at (x: 5.13, y: 13.350000000000001)
# Rect: 2.5 x 3 at (x: 7.63, y: 16.25)
# Rect: 2 x 3.7 at (x: 10.129999999999999, y: 16.25)
# Rect: 2 x 3 at (x: 15.88, y: 5.0)
# Rect: 2 x 3 at (x: 11.850000000000001, y: 12.72)
# Rect: 2 x 2.6 at (x: 12.129999999999999, y: 15.72)
# Rect: 2.2 x 2.25 at (x: 13.850000000000001, y: 12.72)
# Rect: 2.35 x 2 at (x: 16.05, y: 10.95)
# Rect: 1.5 x 2.5 at (x: 18.400000000000002, y: 10.95)
# Rect: 1.2 x 2.75 at (x: 18.78, y: 8.1)
# Rect: 1 x 2 at (x: 8.33, y: 13.350000000000001)
# Rect: 1 x 1 at (x: 14.88, y: 10.95)
#
# Bin 1 (20x20):
#   Rect 18.2x2.7 at (x: 0, y: 0)
#   Rect 18.2x2.7 at (x: 0, y: 2.7)
#   Rect 7x7 at (x: 0, y: 5.4)
#   Rect 12x2.95 at (x: 7, y: 5.4)
#   Rect 12x2.95 at (x: 7, y: 8.350000000000001)
#   Rect 12.1x2.9 at (x: 7, y: 11.3)
#   Rect 12.1x2.9 at (x: 0, y: 14.200000000000001)
#   Rect 13.4x2.5 at (x: 0, y: 17.1)
#   Rect 7.05x2.8 at (x: 12.1, y: 14.200000000000001)
#   Rect 6.3x2.75 at (x: 13.4, y: 17.0)
#   Rect 1x8 at (x: 19, y: 0)
#   Rect 1.76x1.76 at (x: 0, y: 12.4)
#   Rect 1x2.5 at (x: 19, y: 8)
#   Rect 0.8x1.425 at (x: 18.2, y: 0)
#   Rect 0.8x1.2 at (x: 18.2, y: 1.425)
#
# Bin 2 (20x20):
#   Rect 11.5x2.9 at (x: 0, y: 0)
#   Rect 2.65x12.55 at (x: 0, y: 2.9)
#   Rect 12.55x2.65 at (x: 0, y: 15.450000000000001)
#   Rect 2.85x10.7 at (x: 2.65, y: 2.9)
#   Rect 3.36x8.9 at (x: 5.5, y: 2.9)
#   Rect 10.6x2.8 at (x: 8.86, y: 2.9)
#   Rect 8.5x3.35 at (x: 5.5, y: 11.8)
#   Rect 9.02x3.1 at (x: 8.86, y: 5.699999999999999)
#   Rect 9.65x2.82 at (x: 8.86, y: 8.799999999999999)
#   Rect 2.95x8.15 at (x: 14.0, y: 11.62)
#   Rect 2.95x8.15 at (x: 16.95, y: 11.62)
#   Rect 8.5x2.8 at (x: 11.5, y: 0)
#   Rect 2x3 at (x: 17.88, y: 5.699999999999999)
#   Rect 1.4x4 at (x: 12.55, y: 15.15)
#   Rect 2.85x1.6 at (x: 2.65, y: 13.6)
#   Rect 0.5x1.2 at (x: 19.46, y: 8.7)
#
# Bin 3 (20x20):
#   Rect 9.45x2.85 at (x: 0, y: 0)
#   Rect 2.52x10.6 at (x: 0, y: 2.85)
#   Rect 8.75x3.05 at (x: 9.45, y: 0)
#   Rect 9.4x2.75 at (x: 0, y: 13.45)
#   Rect 11x2.22 at (x: 0, y: 16.2)
#   Rect 2.24x10.85 at (x: 9.4, y: 3.05)
#   Rect 2.24x10.85 at (x: 11.64, y: 3.05)
#   Rect 2.24x10.85 at (x: 13.88, y: 3.05)
#   Rect 2.24x10.85 at (x: 16.12, y: 3.05)
#   Rect 8.92x2.63 at (x: 11, y: 13.899999999999999)
#   Rect 8.92x2.63 at (x: 11, y: 16.529999999999998)
#   Rect 2.63x8.92 at (x: 2.52, y: 2.85)
#   Rect 2.63x8.92 at (x: 5.15, y: 2.85)
#   Rect 8x1.5 at (x: 0, y: 18.419999999999998)
#   Rect 1.42x7.43 at (x: 7.78, y: 2.85)
#   Rect 1.3x4.3 at (x: 18.36, y: 0)
#   Rect 2.7x1.5 at (x: 8, y: 18.419999999999998)
#   Rect 2.45x1.65 at (x: 2.52, y: 11.77)
#   Rect 1.5x2.4 at (x: 7.78, y: 10.28)
#   Rect 1.5x1.5 at (x: 9.4, y: 13.899999999999999)
#   Rect 1.5x1.5 at (x: 18.36, y: 4.3)
#
# Bin 4 (20x20):
#   Rect 8.1x2.8 at (x: 0, y: 0)
#   Rect 8.65x2.6 at (x: 8.1, y: 0)
#   Rect 2.25x9.7 at (x: 16.75, y: 0)
#   Rect 8x2.7 at (x: 8.1, y: 2.6)
#   Rect 5.45x3.6 at (x: 0, y: 2.8)
#   Rect 3.65x5.35 at (x: 0, y: 9.7)
#   Rect 2.57x7.52 at (x: 5.45, y: 2.8)
#   Rect 8.7x2.2 at (x: 8.02, y: 5.300000000000001)
#   Rect 6.8x2.75 at (x: 8.02, y: 7.500000000000001)
#   Rect 5.7x3.2 at (x: 0, y: 15.049999999999999)
#   Rect 7x2.5 at (x: 3.65, y: 10.32)
#   Rect 2.61x6.5 at (x: 5.7, y: 12.82)
#   Rect 2.61x6.5 at (x: 8.31, y: 12.82)
#   Rect 4.7x3.6 at (x: 14.82, y: 9.7)
#   Rect 3.6x4.7 at (x: 10.92, y: 10.25)
#   Rect 3.6x4.6 at (x: 10.92, y: 14.95)
#   Rect 4.6x3.55 at (x: 14.52, y: 13.299999999999999)
#   Rect 4.8x2.7 at (x: 14.52, y: 16.849999999999998)
#   Rect 4.88x2.48 at (x: 0, y: 6.4)
#   Rect 1x8 at (x: 19.0, y: 0)
#   Rect 3.7x1.75 at (x: 0, y: 18.25)
#   Rect 2x1.5 at (x: 3.7, y: 18.25)
#   Rect 2x1.5 at (x: 3.65, y: 12.82)
#   Rect 1.6x1.4 at (x: 3.65, y: 8.88)
#   Rect 1x1 at (x: 19.0, y: 8)
#
# Bin 5 (20x20):
#   Rect 7x2.2 at (x: 0, y: 0)
#   Rect 7x2.2 at (x: 7, y: 0)
#   Rect 6x2.5 at (x: 14, y: 0)
#   Rect 6x2.5 at (x: 0, y: 2.2)
#   Rect 6x2.5 at (x: 6, y: 2.2)
#   Rect 6x2.5 at (x: 12, y: 2.5)
#   Rect 6.08x2.42 at (x: 0, y: 4.7)
#   Rect 2.2x6 at (x: 6.08, y: 4.7)
#   Rect 2.1x6.1 at (x: 8.280000000000001, y: 4.7)
#   Rect 1.5x8 at (x: 10.38, y: 4.7)
#   Rect 4.7x2.55 at (x: 0, y: 7.12)
#   Rect 4.7x2.55 at (x: 0, y: 9.67)
#   Rect 4.7x2.55 at (x: 4.7, y: 10.8)
#   Rect 4.32x2.48 at (x: 0, y: 12.219999999999999)
#   Rect 2.48x4.32 at (x: 0, y: 14.7)
#   Rect 1.9x5.6 at (x: 18, y: 2.5)
#   Rect 2.65x3.95 at (x: 2.48, y: 14.7)
#   Rect 4x2.42 at (x: 11.88, y: 5.0)
#   Rect 3.8x2.4 at (x: 11.88, y: 7.42)
#   Rect 3.1x2.85 at (x: 15.68, y: 8.1)
#   Rect 3x2.9 at (x: 11.88, y: 9.82)
#   Rect 2.45x3.55 at (x: 9.4, y: 12.7)
#   Rect 2.5x3.2 at (x: 5.13, y: 16.25)
#   Rect 3.2x2.4 at (x: 5.13, y: 13.350000000000001)
#   Rect 2.5x3 at (x: 7.63, y: 16.25)
#   Rect 2x3.7 at (x: 10.129999999999999, y: 16.25)
#   Rect 2x3 at (x: 15.88, y: 5.0)
#   Rect 2x3 at (x: 11.850000000000001, y: 12.72)
#   Rect 2x2.6 at (x: 12.129999999999999, y: 15.72)
#   Rect 2.2x2.25 at (x: 13.850000000000001, y: 12.72)
#   Rect 2.35x2 at (x: 16.05, y: 10.95)
#   Rect 1.5x2.5 at (x: 18.400000000000002, y: 10.95)
#   Rect 1.2x2.75 at (x: 18.78, y: 8.1)
#   Rect 1x2 at (x: 8.33, y: 13.350000000000001)
#   Rect 1x1 at (x: 14.88, y: 10.95)
